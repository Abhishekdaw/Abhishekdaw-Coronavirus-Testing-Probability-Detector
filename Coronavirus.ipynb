# %%
 import pandas as pd

# %% [markdown]
# ## Reading Data

# %%
df=pd.read_csv('datatest.csv')
df.columns=df.columns.to_series().apply(lambda x:x.strip())

# %%
df
# Out:
#     Fever  Bodypain  Age  RunnyNose  DiffBreathe  InfectionProbability
# 0     100         1   67          1            0                     1
# 1     101         0   28          0            1                     0
# 2     104         1   36          1            1                     1
# 3     104         0    9          0           -1                     1
# 4      99         1   65          0           -1                     0
# ..    ...       ...  ...        ...          ...                   ...
# 94    100         1   51          1            1                     1
# 95    103         0  101          1            1                     0
# 96    100         0   20          0           -1                     0
# 97     98         0   19          1            0                     0
# 98     97         0   22          1            0                     1
#
# [99 rows x 6 columns]

# %%
df.tail()
# Out:
#     Fever   Bodypain  Age  RunnyNose  DiffBreathe  InfectionProbability
# 94     100         1   51          1            1                     1
# 95     103         0  101          1            1                     0
# 96     100         0   20          0           -1                     0
# 97      98         0   19          1            0                     0
# 98      97         0   22          1            0                     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
# Fever                   99 non-null int64
# Bodypain                99 non-null int64
# Age                     99 non-null int64
# RunnyNose               99 non-null int64
# DiffBreathe             99 non-null int64
# InfectionProbability    99 non-null int64
# dtypes: int64(6)
# memory usage: 4.8 KB

# %%
df['DiffBreathe'].value_counts()
# Out:
#  0    42
#  1    30
# -1    27
# Name: DiffBreathe, dtype: int64

# %%
df.describe()
# Out:
#            Fever    Bodypain         Age  RunnyNose  DiffBreathe  \
# count   99.000000  99.000000   99.000000  99.000000    99.000000
# mean   100.161616   0.515152   51.515152   0.494949     0.030303
# std      2.136691   0.502314   30.379694   0.502519     0.762040
# min     97.000000   0.000000    1.000000   0.000000    -1.000000
# 25%     98.000000   0.000000   23.500000   0.000000    -1.000000
# 50%    100.000000   1.000000   49.000000   0.000000     0.000000
# 75%    102.000000   1.000000   76.500000   1.000000     1.000000
# max    104.000000   1.000000  104.000000   1.000000     1.000000
#
#        InfectionProbability
# count             99.000000
# mean               0.525253
# std                0.501903
# min                0.000000
# 25%                0.000000
# 50%                1.000000
# 75%                1.000000
# max                1.000000

# %% [markdown]
# # Train Test splitting

# %%
import numpy as np

# %%
def data_split(data,ratio):
    np.random.seed(42)
    shuffled=np.random.permutation(len(data))
    test_setsize=int(len(data)*ratio)
    test_indices=shuffled[:test_setsize]
    train_indices=shuffled[test_setsize:]
    return data.iloc[test_indices],data.iloc[train_indices]

# %%
train,test=data_split(df,0.3)

# %%
train
train.columns=train.columns.to_series().apply(lambda x: x.strip())

# %%
test
test.columns=test.columns.to_series().apply(lambda x: x.strip())

# %%
train
# Out:
#     Fever  Bodypain  Age  RunnyNose  DiffBreathe  InfectionProbability
# 62     97         1  104          1            0                     0
# 40    100         1   93          0            0                     1
# 95    103         0  101          1            1                     0
# 18    102         1   90          0            1                     0
# 97     98         0   19          1            0                     0
# 84     97         1   14          0            0                     0
# 64     99         1   35          1            0                     0
# 42    100         0   76          1           -1                     1
# 10    103         0   79          1            0                     1
# 0     100         1   67          1            0                     1
# 31     97         1   97          0            0                     1
# 76    102         1   72          0            0                     1
# ...

# %%
test
# Out:
#     Fever  Bodypain  Age  RunnyNose  DiffBreathe  InfectionProbability
# 65     98         1   11          1            0                     0
# 94    100         1   51          1            1                     1
# 30    101         1   32          1            0                     1
# 28    103         1   42          0            0                     1
# 89    102         0   51          1           -1                     1
# ..    ...       ...  ...        ...          ...                   ...
# 60     97         0   47          1           -1                     0
# 71    100         0   30          0            1                     1
# 14    100         0  103          1            1                     0
# 92    101         1    1          0            0                     0
# 51    103         1   37          1            0                     1
#
# [70 rows x 6 columns]

# %%
X_train=train[['Fever','Bodypain','Age','RunnyNose', 'DiffBreathe']].to_numpy()
X_test=test[['Fever' ,'Bodypain', 'Age', 'RunnyNose', 'DiffBreathe']].to_numpy()

# %%
Y_train=train[['InfectionProbability']].to_numpy().reshape(29,)
Y_test=test[['InfectionProbability']].to_numpy().reshape(70,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
clf.predict_proba([[100,1,22,-1,1]])[0][0]
# Out:
# 0.31094202622146516
